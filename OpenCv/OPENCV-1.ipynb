# %%
import cv2

# %%
image = cv2.imread('./images/flowers.jpeg')

# %%
from matplotlib import pyplot as plt

#Show the image with matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
def imshow(title ="" , image=None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show

# %%
imshow('Displaying Our Flowers', image)

# %%
#Kaydetme Biçimleri

cv2.imwrite('output.jpg', image)

cv2.imwrite('output.png', image)
# Out:
# True

# %% [markdown]
# Görüntüler bir dizi(array) olarak tutulur.

# %%
print('Görüntünün Uzunluğu: {} piksel'.format(int(image.shape[0])))
print('Görüntünün Genişliği: {} piksel'.format(int(image.shape[1])))
print('Görüntünün Derinliği: {} renk bileşeni'.format(int(image.shape[2])))
# Out:
# Görüntünün Uzunluğu: 960 piksel
# Görüntünün Genişliği: 1280 piksel
# Görüntünün Derinliği: 3 renk bileşeni
